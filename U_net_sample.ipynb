# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewGavluk/PythonML/blob/main/U_net_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 Подготавливаем параметры
# ## 1.1 Подключаем библиотеки

# %%
# %matplotlib inline
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img, save_img
from IPython.display import Image
from random import uniform
from google.colab import files


from keras.layers import Input, Conv2D, Lambda, MaxPooling2D, Conv2DTranspose, concatenate, Dropout, BatchNormalization
from keras.models import Model, load_model
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import random
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1.2 Загружаем файлы

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d956ec9-169b-40ae-adbc-05513831bc32" name="files[]" multiple disabled />
#      <output id="result-6d956ec9-169b-40ae-adbc-05513831bc32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Train1_1.jpg to Train1_1.jpg
# Saving Train1_1_1.gif to Train1_1_1.gif
# Saving Train1_1_2.gif to Train1_1_2.gif
# Saving Train1_1_3.gif to Train1_1_3.gif
# Saving Train1_1_4.gif to Train1_1_4.gif
# Saving Train1_2.jpg to Train1_2.jpg
# Saving Train1_2_1.gif to Train1_2_1.gif
# Saving Train1_2_2.gif to Train1_2_2.gif
# Saving Train1_2_3.gif to Train1_2_3.gif
# Saving Train1_2_4.gif to Train1_2_4.gif
# Saving Train1_3.jpg to Train1_3.jpg
# Saving Train1_3_1.gif to Train1_3_1.gif
# Saving Train1_3_2.gif to Train1_3_2.gif
# Saving Train1_3_3.gif to Train1_3_3.gif
# Saving Train1_3_4.gif to Train1_3_4.gif
# Saving Train2_1.jpg to Train2_1.jpg
# Saving Train2_1_1.gif to Train2_1_1.gif
# Saving Train2_1_2.gif to Train2_1_2.gif
# Saving Train2_1_3.gif to Train2_1_3.gif
# Saving Train2_1_4.gif to Train2_1_4.gif
# Saving Train2_2.jpg to Train2_2.jpg
# Saving Train2_2_1.gif to Train2_2_1.gif
# Saving Train2_2_2.gif to Train2_2_2.gif
# Saving Train2_2_3.gif to Train2_2_3.gif
# Saving Train2_2_4.gif to Train2_2_4.gif
# Saving Train2_3.jpg to Train2_3.jpg
# Saving Train2_3_1.gif to Train2_3_1.gif
# Saving Train2_3_2.gif to Train2_3_2.gif
# Saving Train2_3_3.gif to Train2_3_3.gif
# Saving Train2_3_4.gif to Train2_3_4.gif
# Saving Train3_1.jpg to Train3_1.jpg
# Saving Train3_1_1.gif to Train3_1_1.gif
# Saving Train3_1_2.gif to Train3_1_2.gif
# Saving Train3_1_3.gif to Train3_1_3.gif
# Saving Train3_1_4.gif to Train3_1_4.gif
# Saving Train3_2.jpg to Train3_2.jpg
# Saving Train3_2_1.gif to Train3_2_1.gif
# Saving Train3_2_2.gif to Train3_2_2.gif
# Saving Train3_2_3.gif to Train3_2_3.gif
# Saving Train3_2_4.gif to Train3_2_4.gif
# Saving Train3_3.jpg to Train3_3.jpg
# Saving Train3_3_1.gif to Train3_3_1.gif
# Saving Train3_3_2.gif to Train3_3_2.gif
# Saving Train3_3_3.gif to Train3_3_3.gif
# Saving Train3_3_4.gif to Train3_3_4.gif
# Saving Train4_1.jpg to Train4_1.jpg
# Saving Train4_1_1.gif to Train4_1_1.gif
# Saving Train4_1_2.gif to Train4_1_2.gif
# Saving Train4_1_3.gif to Train4_1_3.gif
# Saving Train4_1_4.gif to Train4_1_4.gif
# Saving Train4_2.jpg to Train4_2.jpg
# Saving Train4_2_1.gif to Train4_2_1.gif
# Saving Train4_2_2.gif to Train4_2_2.gif
# Saving Train4_2_3.gif to Train4_2_3.gif
# Saving Train4_2_4.gif to Train4_2_4.gif
# Saving Train4_3.jpg to Train4_3.jpg
# Saving Train4_3_1.gif to Train4_3_1.gif
# Saving Train4_3_2.gif to Train4_3_2.gif
# Saving Train4_3_3.gif to Train4_3_3.gif
# Saving Train4_3_4.gif to Train4_3_4.gif

# %% [markdown]
# ##1.3 Устанавливаем значения нач параметров

# %%
HETGHT = 384 
WIDTH = 512

X1crop =28
X2crop =540
Y1crop =20
Y2crop =404

PICTURES=12
ADDITION_CHANELS = 4 # one for each dish
VARIENTY = 100 # rescaled copies of picture
IMG_CHANNELS = 3

BATCH_SIZE      = 24
NUM_EPOCHS      = 100
LR              = 1e-5
validation_split= 0.1

# learning rate
LR = 1e-4

# %% [markdown]
# # 2 Подготавливаем функции
# ## 2.1 getPicture
#
# Предназначена для считывания картинки и получения массива

# %%
# read picture from imgName return array
def getPicture (imgName,     # picture to read 
                pict=False,  # enable if RGB-picture disable if mask 
                show=False): # enable to see your picture
   
    # load image as as grayscale
    if show: 
      print(imgName)
    preImg = load_img(imgName, grayscale=False)
    img=preImg.crop((28,20,540,404))
    
    # convert image to a numpy array
    img_array256 = img_to_array(img)
    img_array = img_array256 / 256
    
    #set Ndim if RGB-Piture Ndim=3 else it is mask Ndim=1
    if pict:
      train_image = np.tile(img_array[:, :, 0][:, :, np.newaxis], (1, 1, 3))
      if show: 
        plt.imshow(train_image[0:HETGHT, 0:WIDTH])
    else:
      train_image = np.tile(img_array[:, :, 0][:, :, np.newaxis], (1, 1, 1))
      
      
    return train_image

# %% [markdown]
# ## 2.2 loadImgAndMasks
# Предназначена для создания "большой картинки" - картинки из RGB каналов и масок каждого из блюд

# %%
# read "small image" and masks then concatenate it "big image" 
def loadImgAndMasks (imgNames,    # image and masks name
                     show=False):
    
    # load image
    picture = getPicture (imgNames[0], True, show)
    if show:
        print("picture.shape = ", picture.shape)
    else: 
        print ("processing ", imgNames[0])
       
  
    for i in range(ADDITION_CHANELS):
      # load mask
      mask = getPicture (imgNames[i+1], False, show)
      if show:
        print("mask" + str(i+1) + ".shape   = ", mask.shape)
      picture=np.concatenate([picture, mask], axis=2)
        
    return picture

# %% [markdown]
# ## 2.2 generateBatch
# Генерируем батч разнообразия

# %%
def generatePicture (datagen, maskshow, parameters):
      newPictures255=datagen.apply_transform(maskshow, transform_parameters=parameters)
      newPictures=newPictures255/255
      return newPictures 


def showPicture (fig, rows, cols, i, pic):
      
      ax = fig.add_subplot(rows, cols, i )
      ax.grid('off')
      ax.axis('on') 
      ax.imshow(pic[0:HETGHT, 0:WIDTH])


def generateBatch (masksPictures,
                   iShow=0):      # Shows how much pictures will show in batch 

    
    datagen = ImageDataGenerator()

    cols = ADDITION_CHANELS + 1
    rows = VARIENTY
    fig = plt.figure(figsize=(5 * cols - 1, 5 * rows - 1))
    
    for i in range(VARIENTY):
      
      # define random generator parametrs 
      parameters={'theta':uniform(-45, 45), 'brightness':1.0, 'zx':uniform(0.5, 1.5), 'zy':uniform(0.5, 1.5), 'shear':uniform(-25, 25)}
      
      # change picture with params
      maskshow=masksPictures[:,:,0:3]
      newPicture = generatePicture (datagen, maskshow, parameters)
      if  i<iShow: 
        showPicture (fig, rows, cols, i*5+1, newPicture)

      for j in range(ADDITION_CHANELS):
          
          # change masks with params
          mask=masksPictures[:, :, 3+j:4+j]
          
          if i<iShow:
            maskshow = np.tile(mask[:, :, 0][:, :, np.newaxis], (1, 1, 3))
            newMask = generatePicture (datagen, maskshow, parameters)
            showPicture (fig, rows, cols, i*5+j+2, newMask)
          
          maskshow = np.tile(mask[:, :][:, :], (1, 1))
          newMask = generatePicture (datagen, maskshow, parameters)
          
          # add next chanel to picture 
          newPicture=np.concatenate([newPicture, newMask], axis=2)
       
      # produce 4d tensor 
      if i==0:
        # add 4-th dim to 3-d tensor
        oldBatch = np.expand_dims(newPicture, 0)  
      else:
        newPicture = np.expand_dims(newPicture, 0)
        oldBatch=np.concatenate([oldBatch, newPicture], axis=0)
      #print("oldBatch.shape=", oldBatch.shape) 
      
    return oldBatch

# %%
trainList = list()
trainList.append("Train1_1.jpg")
trainList.append("Train1_1_1.gif")
trainList.append("Train1_1_2.gif")
trainList.append("Train1_1_3.gif")
trainList.append("Train1_1_4.gif")
Train1_1 = loadImgAndMasks(trainList, True)
# Out:
# Train1_1.jpg
# picture.shape =  (384, 512, 3)
# Train1_1_1.gif
# mask1.shape   =  (384, 512, 1)
# Train1_1_2.gif
# mask2.shape   =  (384, 512, 1)
# Train1_1_3.gif
# mask3.shape   =  (384, 512, 1)
# Train1_1_4.gif
# mask4.shape   =  (384, 512, 1)

# %% [markdown]
# ## 3.2 Проверка работы generateBatch

# %%
Train1_1Batch = generateBatch(Train1_1, True)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# ## 4.1 Генерация

# %%
#batch = 0
def genDataset():
  for i in range(1, 5):    # dish cycle 
    for j in range(1, 4):  # "big picture" cycle
    
    # list of filenames for "big picture"
      sMasks = list()
      sPicture = "Train" + str(i) + "_" + str(j) + ".jpg"
      sMasks.append(sPicture)
      for k in range (ADDITION_CHANELS):# masks cycle 
        name = "Train" + str(i) + "_" + str(j) + "_" + str(k+1) + ".gif"
        sMasks.append(name)
    
      bigPicture = loadImgAndMasks(sMasks) 
    
      if i==1 and j==1:
        batch = generateBatch(bigPicture)
      else:
        new_batch = generateBatch(bigPicture)
        batch = np.concatenate([batch, new_batch], axis=0) 
      print(batch.shape)
    
  return batch;

# %% [markdown]
# # 4. Подготовка датасета

# %%
Dataset =genDataset()
print(Dataset.shape)
# Out:
# processing  Train1_1.jpg
# (100, 384, 512, 7)
# processing  Train1_2.jpg
# (200, 384, 512, 7)
# processing  Train1_3.jpg
# (300, 384, 512, 7)
# processing  Train2_1.jpg
# (400, 384, 512, 7)
# processing  Train2_2.jpg
# (500, 384, 512, 7)
# processing  Train2_3.jpg
# (600, 384, 512, 7)
# processing  Train3_1.jpg
# (700, 384, 512, 7)
# processing  Train3_2.jpg
# (800, 384, 512, 7)
# processing  Train3_3.jpg
# (900, 384, 512, 7)
# processing  Train4_1.jpg
# (1000, 384, 512, 7)
# processing  Train4_2.jpg
# (1100, 384, 512, 7)
# processing  Train4_3.jpg
# (1200, 384, 512, 7)
# (1200, 384, 512, 7)

# %% [markdown]
# ## 4.2 Перемешивание

# %%
mixedDataset = Dataset
#for i in range(VARIENTY*PICTURES):
#  i1= i // PICTURES
#  i2= i %  PICTURES
#  mixedDataset[i, :, :, :] = Dataset[i2*VARIENTY+i1, :, :, :]

print(mixedDataset.shape)
  
# 
xTrain = mixedDataset[:,:,:,0:3]
yTrain = mixedDataset[:,:,:,3:7]

# inverting masks
yTrain = 1.-yTrain 
yTrain = (yTrain > 0.9)


print(xTrain.shape)
print(yTrain.shape)
# Out:
# (1200, 384, 512, 7)
# (1200, 384, 512, 3)
# (1200, 384, 512, 4)

# %% [markdown]
# ## 4.3 Проверка

# %%
Numb =50

maskSample = xTrain[Numb, :,:,:]
plt.imshow(maskSample[0:HETGHT, 0:WIDTH])

fig = plt.figure(figsize=(25, 10))

pic=yTrain[Numb, :,:,0]
showPicture (fig, 3, 4, 5, pic)
pic=yTrain[Numb, :,:,1]
showPicture (fig, 3, 4, 6, pic)
pic=yTrain[Numb, :,:,2]
showPicture (fig, 3, 4, 7, pic)
pic=yTrain[Numb, :,:,3]
showPicture (fig, 3, 4, 8, pic)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# # 5.Обучаем нейросеть
# ## 5.1 Собираем нейросеть

# %%
DropoutL1 = 0.85
DropoutL2 = 0.9
DropoutL3 = 0.95

# Build U-Net model
inputs = Input((HETGHT, WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x ) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(DropoutL1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(DropoutL1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(DropoutL2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(DropoutL2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = BatchNormalization() (c5)
c5 = Dropout(DropoutL3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(DropoutL2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(DropoutL2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(DropoutL1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(DropoutL1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(ADDITION_CHANELS, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
optimizer = Adam(lr=LR,)
model.compile(optimizer=optimizer, loss='binary_crossentropy',)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 384, 512, 3)  0
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 384, 512, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 384, 512, 16) 448         lambda_3[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 384, 512, 16) 0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 384, 512, 16) 2320        dropout_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 192, 256, 16) 0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 192, 256, 32) 4640        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 192, 256, 32) 0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 192, 256, 32) 9248        dropout_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 96, 128, 32)  0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 96, 128, 64)  18496       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 96, 128, 64)  0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 96, 128, 64)  36928       dropout_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 48, 64, 64)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 48, 64, 128)  73856       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 48, 64, 128)  0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 48, 64, 128)  147584      dropout_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 24, 32, 128)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 24, 32, 256)  295168      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 24, 32, 256)  1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 24, 32, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 24, 32, 256)  590080      dropout_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 48, 64, 128)  131200      conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 48, 64, 256)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 48, 64, 128)  295040      concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 48, 64, 128)  0           conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 48, 64, 128)  147584      dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 96, 128, 64)  32832       conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 96, 128, 128) 0           conv2d_transpose_10[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 96, 128, 64)  73792       concatenate_10[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 96, 128, 64)  0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 96, 128, 64)  36928       dropout_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 192, 256, 32) 8224        conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 192, 256, 64) 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 192, 256, 32) 18464       concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 192, 256, 32) 0           conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 192, 256, 32) 9248        dropout_26[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 384, 512, 16) 2064        conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 384, 512, 32) 0           conv2d_transpose_12[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 384, 512, 16) 4624        concatenate_12[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 384, 512, 16) 0           conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 384, 512, 16) 2320        dropout_27[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 384, 512, 4)  68          conv2d_56[0][0]
# ==================================================================================================
# Total params: 1,942,180
# Trainable params: 1,941,668
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %% [markdown]
# ## 5.2 Обучаем нейросеть

# %%
# Fit model
history = model.fit(xTrain, yTrain, 
                    validation_split=validation_split, 
                    batch_size=BATCH_SIZE, 
                    epochs=NUM_EPOCHS, 
                    verbose=1)
# Out:
# Train on 1080 samples, validate on 120 samples
# Epoch 1/100
# 1080/1080 [==============================] - 76s 70ms/step - loss: 3.9483 - val_loss: 0.6528
# Epoch 2/100
# 1080/1080 [==============================] - 73s 68ms/step - loss: 1.3000 - val_loss: 0.4477
# Epoch 3/100
# 1080/1080 [==============================] - 73s 68ms/step - loss: 0.9962 - val_loss: 0.2773
# Epoch 4/100
# 1080/1080 [==============================] - 73s 67ms/step - loss: 0.7866 - val_loss: 0.2305
# Epoch 5/100
# 1080/1080 [==============================] - 73s 67ms/step - loss: 0.6378 - val_loss: 0.2248
# Epoch 6/100
# 1080/1080 [==============================] - 73s 67ms/step - loss: 0.5338 - val_loss: 0.2290
# Epoch 62/100
# 1080/1080 [==============================] - 73s 68ms/step - loss: 0.1784 - val_loss: 0.6140
# Epoch 63/100
# 1080/1080 [==============================] - 73s 68ms/step - loss: 0.1775 - val_loss: 0.6048
# Epoch 64/100
# 1080/1080 [==============================] - 73s 68ms/step - loss: 0.1766 - val_loss: 0.6079
# Epoch 65/100
# 1080/1080 [==============================] - 73s 68ms/step - loss: 0.1759 - val_loss: 0.6021
# Epoch 66/100
# 1080/1080 [==============================] - 73s 68ms/step - loss: 0.1752 - val_loss: 0.6014
# Epoch 67/100
# 1080/1080 [==============================] - 73s 67ms/step - loss: 0.1744 - val_loss: 0.5846
# Epoch 68/100
#  216/1080 [=====>........................] - ETA: 55s - loss: 0.1811
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-0591de9d762f> in <module>()
#       3                     batch_size=BATCH_SIZE,
#       4                     epochs=NUM_EPOCHS,
# ----> 5                     verbose=1)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model.save('keras_unet.h5')

# %% [markdown]
# ## 5.3 Функция потерь

# %%
def plot_loss_history(history):
    # validation losses
    val_loss = history.history['val_loss']
    loss = history.history['loss']

    plt.title('Loss')
    plt.plot(val_loss, 'r', loss, 'b')
    plt.show()
    
plot_loss_history(history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-df832bdef052> in <module>()
#       8     plt.show()
#       9
# ---> 10 plot_loss_history(history)
#
# NameError: name 'history' is not defined

# %%
yPredict = model.predict(xTrain, verbose=1)
yPredict.shape
# Out:
# 1200/1200 [==============================] - 32s 26ms/step
# (1200, 384, 512, 4)

# %%
image_sample = xTrain[41, :,:,:]
plt.imshow(image_sample[0:HETGHT, 0:WIDTH])

# %%
maskSample = yTrain[41, :,:,1]
plt.imshow(maskSample[0:HETGHT, 0:WIDTH])

# %%
maskSample = yPredict[41, :,:,3]
plt.imshow(maskSample[0:HETGHT, 0:WIDTH])

# %%
Numb=52

maskSample = xTrain[Numb, :,:,:]
plt.imshow(maskSample[0:HETGHT, 0:WIDTH])

fig = plt.figure(figsize=(25, 10))

pic=yTrain[Numb, :,:,0]
showPicture (fig, 3, 4, 5, pic)
pic=yTrain[Numb, :,:,1]
showPicture (fig, 3, 4, 6, pic)
pic=yTrain[Numb, :,:,2]
showPicture (fig, 3, 4, 7, pic)
pic=yTrain[Numb, :,:,3]
showPicture (fig, 3, 4, 8, pic)

pic=yPredict[Numb, :,:,0]
showPicture (fig, 3, 4, 9, pic)
pic=yPredict[Numb, :,:,1]
showPicture (fig, 3, 4, 10, pic)
pic=yPredict[Numb, :,:,2]
showPicture (fig, 3, 4, 11, pic)
pic=yPredict[Numb, :,:,3]
showPicture (fig, 3, 4, 12, pic)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
